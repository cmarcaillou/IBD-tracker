# %%
pip install ruptures
# Out:
# Collecting ruptures
#   Downloading ruptures-1.1.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ruptures) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from ruptures) (1.11.4)
# Installing collected packages: ruptures
# Successfully installed ruptures-1.1.9

# %%
# @title Data Reading
import pandas as pd
import random
import seaborn as sns
import numpy as np
import ruptures as rpt
import time
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score
from scipy.stats import gmean

gene_count_path ='/content/drive/MyDrive/MITResearch/IBD_13/gene_count_preprocessed.csv'
metaphlan_path = '/content/drive/MyDrive/MITResearch/IBD_13/metaphlan_preprocessed.csv'

gene_count_df = pd.read_csv(gene_count_path)
metaphlan_df = pd.read_csv(metaphlan_path)

print(gene_count_df.shape)
print(metaphlan_df.shape)
# Out:
# (605, 546)
# (479, 1453)

# %%
 def clr_transform(df, metadata_columns):
    species_data = df.drop(columns=metadata_columns)
    species_data += 1e-5
    geometric_means = gmean(species_data, axis=1)
    clr_transformed_data = np.log(species_data.divide(geometric_means, axis=0))
    clr_transformed_df = pd.concat([df[metadata_columns], clr_transformed_data], axis=1)
    return clr_transformed_df

metaphlan_df = clr_transform(metaphlan_df, ['patient_id', 'week', 'Flare_status'])

# %%
# @title Adding a Flare_start column function

def flag_first_flare_weeks(df):
    # Identify the rows where flare starts
    df['is_flare'] = (df['Flare_status'] == 'During_flare') | (df['Flare_status'] == 'During_flare_2')

    # Sort by patient and week to ensure the chronological order
    df.sort_values(by=['patient_id', 'week'], inplace=True)

    # Mark each flare start for each patient
    df['Flare_start'] = (df['is_flare']) & (df['is_flare'] != df['is_flare'].shift(1))

    # Convert boolean to integer (1 for True, 0 for False)
    df['Flare_start'] = df['Flare_start'].astype(int)

    # Drop helper columns if they are no longer needed
    df.drop('is_flare', axis=1, inplace=True)

    return df

# %%
# @title Adding a Flare_start column
metaphlan_df = flag_first_flare_weeks(metaphlan_df)
gene_count_df = flag_first_flare_weeks(gene_count_df)

# %%
gene_count_df.dtypes
# Out:
# Flare_status                               object
# patient_id                                 object
# week                                        int64
# ABCA1_ENSG00000165029_ENST00000678995     float64
# ABCA8_ENSG00000141338_ENST00000586539     float64
#                                            ...
# MUC19_ENSG00000205592_ENST00000454784     float64
# NLRP7_ENSG00000167634_ENST00000588756     float64
# ORMDL3_ENSG00000172057_ENST00000394169    float64
# TSLP_ENSG00000145777_ENST00000344895      float64
# Flare_start                                 int64
# Length: 547, dtype: object

# %%
metaphlan_df = metaphlan_df.sort_values(by=['patient_id', 'week'])

# Function to find weeks with Flare_status change
def find_flare_changes(group):
    # Detect changes by comparing each element with the previous one
    changes = group['Flare_status'].ne(group['Flare_status'].shift(1))
    if changes.any():  # If there are any changes
        change_weeks = group.loc[changes, 'week']
        print(f"Patient {group['patient_id'].iloc[0]} has Flare_status changes in weeks: {list(change_weeks)}")

# Group by patient_id and apply the function
metaphlan_df.groupby('patient_id').apply(find_flare_changes)
# Out:
# Patient TR_2101 has Flare_status changes in weeks: [1, 25, 44]
# Patient TR_2102 has Flare_status changes in weeks: [1, 16, 29]
# Patient TR_2103 has Flare_status changes in weeks: [1, 27, 42, 51, 52]
# Patient TR_2104 has Flare_status changes in weeks: [1, 43, 47]
# Patient TR_2105 has Flare_status changes in weeks: [1]
# Patient TR_2106 has Flare_status changes in weeks: [0, 4, 52]
# Patient TR_2107 has Flare_status changes in weeks: [0, 10, 12, 15, 20, 33, 39]
# Patient TR_2108 has Flare_status changes in weeks: [16]
# Patient TR_2201 has Flare_status changes in weeks: [1, 7, 8, 9, 15, 16, 18, 22, 23, 24, 31, 32, 33, 47, 48, 49]
# Patient TR_2202 has Flare_status changes in weeks: [1]
# Patient TR_2203 has Flare_status changes in weeks: [0]
# Patient TR_2205 has Flare_status changes in weeks: [39]
# Empty DataFrame
# Columns: []
# Index: []

# %%
def print_flare_start_indices(df):
  def find_flare_start_indices(group):
      indices = group.index[group['Flare_start'] == 1].tolist()
      return [group.index.get_loc(idx) for idx in indices]

  # Apply the function to each group
  flare_indices = df.groupby('patient_id').apply(find_flare_start_indices)

  print(flare_indices)

print("Flare start indices for metaphlan_df")
print(print_flare_start_indices(metaphlan_df))
print("Flare start indices for gene_count_df")
print(print_flare_start_indices(gene_count_df))
# Out:
# Flare start indices for metaphlan_df
# patient_id
# TR_2101        [22]
# TR_2102        [12]
# TR_2103    [24, 42]
# TR_2104          []
# TR_2105          []
# TR_2106          []
# TR_2107          []
# TR_2108          []
# TR_2201          []
# TR_2202          []
# TR_2203          []
# TR_2205          []
# dtype: object
# None
# Flare start indices for gene_count_df
# patient_id
# TR_2101        [25]
# TR_2102        [11]
# TR_2103    [25, 46]
# TR_2104          []
# TR_2105          []
# TR_2106          []
# TR_2107          []
# TR_2108          []
# TR_2201          []
# TR_2202          []
# TR_2203          []
# TR_2204          []
# TR_2205          []
# dtype: object
# None

# %% [markdown]
# # Change points detection

# %%
def detect_change_points(data, pen=50):
    """Detect change points in a given time series using the PELT method."""
    model = "l2"
    algo = rpt.Pelt(model=model, min_size=1, jump=1).fit(data)
    result = algo.predict(pen=pen)
    if result[-1] == len(data):
        result = result[:-1]
    return result

def process_patient_data(data, patient_id, columns_to_drop, pen=50, show_plots=True):
    print(f"Processing data for patient ID: {patient_id}")

    # Filter and prepare data
    filtered_df = data[data['patient_id'] == patient_id].drop(columns=columns_to_drop)
    filtered_df = 10 * filtered_df.loc[:, (filtered_df != 0).any(axis=0)]
    species_names = filtered_df.columns.tolist()
    signal = filtered_df.to_numpy()
    print(f"Data prepared with {len(species_names)} species/genes")

    # Detect change points
    change_points = [detect_change_points(signal[:, i], pen) for i in range(signal.shape[1])]
    print("Change point detection complete")

    # Create feature vectors for clustering
    feature_vectors = np.zeros((signal.shape[1], signal.shape[0]))
    for idx, cps in enumerate(change_points):
        if cps:
            feature_vectors[idx, cps] = 1
    print(f"Feature vectors created with non-zero entries: {np.sum(feature_vectors)}")

    # Clustering process
    if np.any(feature_vectors.sum(axis=1)):
        silhouette_scores = []
        range_n_clusters = range(2, max(2, int(sum(feature_vectors.sum(axis=1) > 0) / 2)))
        for num_clusters in range_n_clusters:
            kmeans = KMeans(n_clusters=num_clusters, random_state=42, n_init=10)
            cluster_labels = kmeans.fit_predict(feature_vectors)
            silhouette_avg = silhouette_score(feature_vectors, cluster_labels)
            silhouette_scores.append(silhouette_avg)

        optimal_n_clusters = range_n_clusters[np.argmax(silhouette_scores)]
        kmeans = KMeans(n_clusters=optimal_n_clusters, random_state=42, n_init=10)
        labels = kmeans.fit_predict(feature_vectors)

        # Organize species by cluster and calculate median change points
        clusters = {i: [] for i in range(optimal_n_clusters)}
        median_change_points = {i: [] for i in range(optimal_n_clusters)}
        for label, species in zip(labels, species_names):
            clusters[label].append(species)
            cps = [change_points[species_names.index(s)] for s in clusters[label]]
            cps_flat = [item for sublist in cps for item in sublist]
            if cps_flat:
                median_change_points[label] = np.median(cps_flat)
            else:
                median_change_points[label] = np.nan  # Set as NaN if no change points

        print(f"Optimal number of clusters: {optimal_n_clusters}")

        # Plotting the results, controlled by show_plots flag
        if show_plots:
            for cluster_id, species_list in clusters.items():
                if np.isnan(median_change_points[cluster_id]):
                    plt.figure(figsize=(4, 4))
                    plt.text(0.5, 0.5, 'Median change point is NaN', fontsize=12, ha='center')
                    plt.title(f"Cluster {cluster_id}")
                    plt.axis('off')  # Hide axes
                else:
                    plt.figure(figsize=(12, 6))
                    for species in species_list:
                        timeseries = signal[:, species_names.index(species)]
                        plt.plot(timeseries, label=f"{species} timeseries")
                        plt.axvline(x=median_change_points[cluster_id], color='r', linestyle='--', label='Median Change Point' if species == species_list[0] else "")
                    plt.title(f"Cluster {cluster_id} with median change point at {median_change_points[cluster_id]}")
                    plt.legend()
                plt.show()

        return clusters
    else:
        print("No change points detected across all features; clustering not applicable.")
        return {}

# %%
clusters = process_patient_data(gene_count_df, 'TR_2102', ['Flare_status','patient_id','week', 'Flare_start'], 10000)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
clusters = process_patient_data(metaphlan_df, 'TR_2102', ['Flare_status','patient_id','week'], pen=0.001)
# Out:
# Processing data for patient ID: TR_2102
# Data prepared with 1451 species/genes
# Change point detection complete
# Feature vectors created with non-zero entries: 59883.0
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (21). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (22). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (23). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (24). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (25). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (26). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (27). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (28). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (29). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (30). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (31). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (32). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (33). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (34). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (35). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (36). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (37). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (38). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (39). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (40). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (41). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (42). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (43). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (44). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (45). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (46). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (47). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (48). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (49). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (50). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (51). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (52). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (53). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (54). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (55). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (56). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (57). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (58). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (59). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (60). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (61). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (62). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (63). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (64). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (65). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (66). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (67). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (68). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (69). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (70). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (71). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (72). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (73). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (74). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (75). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (76). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (77). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (78). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (79). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (80). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (81). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (82). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (83). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (84). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (85). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (86). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (87). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (88). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (89). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (90). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (91). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (92). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (93). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (94). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (95). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (96). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (97). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (98). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (99). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (100). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (101). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (102). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (103). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (104). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (105). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (106). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (107). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (108). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (109). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (110). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (111). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (112). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (113). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (114). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (115). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (116). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (117). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (118). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (119). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (120). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (121). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (122). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (123). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (124). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (125). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (126). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (127). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (128). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (129). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (130). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (131). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (132). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (133). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (134). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (135). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (136). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (137). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (138). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (139). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (140). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (141). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (142). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (143). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (144). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (145). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (146). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (147). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (148). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (149). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (150). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (151). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (152). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (153). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (154). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (155). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (156). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (157). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (158). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (159). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (160). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (161). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (162). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (163). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (164). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (165). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (166). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (167). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (168). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (169). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (170). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (171). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (172). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (173). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (174). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (175). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (176). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (177). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (178). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (179). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (180). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (181). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (182). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (183). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (184). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (185). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (186). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (187). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (188). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (189). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (190). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (191). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (192). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (193). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (194). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (195). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (196). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (197). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (198). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (199). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (200). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (201). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (202). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (203). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (204). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (205). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (206). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (207). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (208). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/numpy/core/multiarray.py in where(condition, x, y)
#     344
#     345
# --> 346 @array_function_from_c_func_and_dispatcher(_multiarray_umath.where)
#     347 def where(condition, x=None, y=None):
#     348     """
#
# KeyboardInterrupt:
# Exception ignored in: 'sklearn.cluster._k_means_common._relocate_empty_clusters_dense'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/numpy/core/multiarray.py", line 346, in where
#     @array_function_from_c_func_and_dispatcher(_multiarray_umath.where)
# KeyboardInterrupt:
